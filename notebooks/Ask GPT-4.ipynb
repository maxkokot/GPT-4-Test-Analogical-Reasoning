# %% [markdown]
# # Ask GPT-4
# In this notebook, we form the questions to GPT-4 in accordance to test dataset. Further we send the questions and save the answers for further evaluation.

# %%
import os
import re
import pandas as pd
import openai
import csv
from collections import defaultdict
from dotenv import load_dotenv, find_dotenv

# %%
PH2ANS_DIR = '../data/raw/Testing/Phase2Answers' # test questions and answers provided by humans
PH1QUE_DIR = '../data/raw/Testing/Phase1Questions' # files containing illustrative examples for each subcategory
GPTQUE_DIR = '../data/processed' # processed data for creating questions to GPT-4
GPTANS_DIR = '../data/interim' # answers obtained from GPT-4

# We consider only small subset of whole
# dataset since utilizing all data is costly
SELECTED_IDXS = ['2g', '2a', '10b', '7f', '4d', '4b', '1c', '6d']

Q_TEMPLATE = ("In this line, based on the pairs provided, choose among them the least illustrative "
              "and the most illustrative representation for the kind of relation demonstrated by these examples: {}. "
              "The output should be these four pairs "
              "and the least illustrative and the most illustrative as the 5th and 6th column, accordingly. "
              "The output should be written in one line, 6 pairs overall in the following format: "
              "pair1, pair2, pair3, pair4, least_illustrative, most_illustrative. "
              "And that's it, no brackets, no quotes, nothing else, it must be in this format. "
              "Do not include the examples of the relation in your output! They just provide you examples of a certain relation "
              "and based on this relation (that you infer from these examples) you need to choose the least and most illustrative among the following 4 pairs: ")

# %%
def read_txt_info(path):
    with open(path, 'r') as f:
        info = f.read()
    return info


def read_hum_answers(path):
    df = pd.read_csv(path, sep='\t')
    df = df.rename({'# pair1': 'pair1'}, axis='columns')
    return df


def write_answers(responses, path):
    with open(path, 'w', newline='') as outfile:
        writer = csv.writer(outfile, delimiter='\t')
        for response in responses:
            writer.writerow([response])

# %%
def ask_gpt4(instruction, options):

    response = None
    message = [{"role": "system", "content": instruction},
               {"role": "user", "content": options}]

    # Make API calls for each line
    chat_completion = openai.ChatCompletion.create(
        model="gpt-4",
        messages=message
    )
    # Extracting the assistant's response
    assistant_message = chat_completion['choices'][0]['message']
    if assistant_message['role'] == 'assistant':
        response = assistant_message['content']

    return response

# %% [markdown]
# ## Download the dataset

# %%
# !wget -O ../data/raw/files.zip "https://drive.usercontent.google.com/u/0/uc?id=0BzcZKTSeYL8VX3JvVGkyMGlBNXM&export=download&resourcekey=0-s590MqFTmRTS4RSNZSgtcg"
# !unzip ../data/raw/files.zip  -d ../data/raw/
# !rm ../data/raw/files.zip
# Out:
# --2024-02-26 18:55:57--  https://drive.usercontent.google.com/u/0/uc?id=0BzcZKTSeYL8VX3JvVGkyMGlBNXM&export=download&resourcekey=0-s590MqFTmRTS4RSNZSgtcg
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 216.58.204.225, 2a00:1450:4002:415::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|216.58.204.225|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://drive.usercontent.google.com/uc?id=0BzcZKTSeYL8VX3JvVGkyMGlBNXM&export=download&resourcekey=0-s590MqFTmRTS4RSNZSgtcg [following]
# --2024-02-26 18:55:58--  https://drive.usercontent.google.com/uc?id=0BzcZKTSeYL8VX3JvVGkyMGlBNXM&export=download&resourcekey=0-s590MqFTmRTS4RSNZSgtcg
# Reusing existing connection to drive.usercontent.google.com:443.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=0BzcZKTSeYL8VX3JvVGkyMGlBNXM&export=download&resourcekey=0-s590MqFTmRTS4RSNZSgtcg [following]
# --2024-02-26 18:55:58--  https://drive.usercontent.google.com/download?id=0BzcZKTSeYL8VX3JvVGkyMGlBNXM&export=download&resourcekey=0-s590MqFTmRTS4RSNZSgtcg
# Reusing existing connection to drive.usercontent.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 840145 (820K) [application/octet-stream]
# Saving to: ‘../data/raw/files.zip’
#
# ../data/raw/files.z 100%[===================>] 820,45K  --.-KB/s    in 0,1s
#
# 2024-02-26 18:56:03 (5,90 MB/s) - ‘../data/raw/files.zip’ saved [840145/840145]
#
# Archive:  ../data/raw/files.zip
#    creating: ../data/raw/Examples/
#   inflating: ../data/raw/Examples/MaxDiffRandom-1a.txt
#   inflating: ../data/raw/Examples/TurkerScaled-1a.txt
#   inflating: ../data/raw/Examples/RandomMaxDiff-1a.txt
#   inflating: ../data/raw/Examples/RandomScaled-1a.txt
#   inflating: ../data/raw/Examples/SpearmanRandomScaled-1a.txt
#   inflating: ../data/raw/examples.sh
#   inflating: ../data/raw/maxdiff_to_scale.pl
#   inflating: ../data/raw/Proposal.pdf
#   inflating: ../data/raw/Questionnaire.pdf
#   inflating: ../data/raw/random_scale.pl
#   inflating: ../data/raw/README-scripts.txt
#   inflating: ../data/raw/README.txt
#   inflating: ../data/raw/reversals.txt
#   inflating: ../data/raw/scale_to_maxdiff.pl
#   inflating: ../data/raw/score_maxdiff.pl
#   inflating: ../data/raw/score_scale.pl
#   inflating: ../data/raw/subcategories-definitions.txt
#   inflating: ../data/raw/subcategories-list.txt
#   inflating: ../data/raw/subcategories-paradigms.txt
#   inflating: ../data/raw/subcategories-training.txt
#   inflating: ../data/raw/summary.xls
#   inflating: ../data/raw/Taxonomy.pdf
#   inflating: ../data/raw/Taxonomy.txt
#    creating: ../data/raw/Testing/
#    creating: ../data/raw/Testing/Phase1Answers/
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-10e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-5g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6c.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-1b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-4b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-3e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9h.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-3f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8c.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-5c.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2j.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9c.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-7c.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-4d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-4f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-4g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9i.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-4h.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-5h.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2i.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6h.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-5b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-1e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9a.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-1c.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-5a.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-7b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-10f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-10d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-3d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-1d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-7d.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-10c.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-7f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6a.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-7g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-7e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-7h.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-3b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-4e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-4a.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8a.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-9e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-3h.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-3g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-8h.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-5f.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-10b.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-5e.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-6g.txt
#   inflating: ../data/raw/Testing/Phase1Answers/Phase1Answers-2a.txt
#    creating: ../data/raw/Testing/Phase1Questions/
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-4f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-4e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-1e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2j.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-7d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9c.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9a.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8a.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-3g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8h.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-4a.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-5f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-3f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-10e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-1d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-5e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6h.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-7h.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-10c.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-5g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-7c.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9i.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-9h.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-4d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-3e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-1c.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-4g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6c.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-3b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2a.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6a.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-5h.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-5b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-8c.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-10f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-3h.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-7e.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-6d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-7f.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-4h.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-7g.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-10b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-2i.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-1b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-7b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-5a.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-5c.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-4b.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-3d.txt
#   inflating: ../data/raw/Testing/Phase1Questions/Phase1Questions-10d.txt
#    creating: ../data/raw/Testing/Phase2Questions/
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6c.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-7g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6a.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-5b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9c.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-7f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-1b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9h.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2i.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-3g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-1c.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-7e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-5h.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-4h.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8h.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-4e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-3e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6h.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8c.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-3h.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-5a.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-4b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-1d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-1e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-5e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-10b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-7b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-4g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-10d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-3b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-10c.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-10f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-10e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6e.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-5f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2j.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-4f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-4d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-3f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-7d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9a.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9f.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-9i.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-3d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-4a.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-5c.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8b.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-8a.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-5g.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-7c.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-6d.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-2a.txt
#   inflating: ../data/raw/Testing/Phase2Questions/Phase2Questions-7h.txt
#    creating: ../data/raw/Testing/Phase2Answers/
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9g.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-7d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-10f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-7h.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-10b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-4f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9c.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-1d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9a.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6c.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-4a.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-1e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-7f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2a.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6h.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2g.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8g.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-1b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-7c.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2i.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-5a.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-4d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-10d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2j.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9h.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-5b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-7b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-3e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-10e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-5e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-3g.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-4e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6a.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-4g.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-5h.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-5f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-5c.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-2e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-7g.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-4b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-7e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-3h.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9i.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8c.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-1c.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-9f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8a.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-4h.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-3d.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-10c.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8e.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-3f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6f.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-5g.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-3b.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-8h.txt
#   inflating: ../data/raw/Testing/Phase2Answers/Phase2Answers-6g.txt
#    creating: ../data/raw/Training/
#    creating: ../data/raw/Training/Phase1Answers/
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-5i.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-3a.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-2c.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-2h.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-3c.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-10a.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-4c.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-1a.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-5d.txt
#   inflating: ../data/raw/Training/Phase1Answers/Phase1Answers-7a.txt
#    creating: ../data/raw/Training/Phase1Questions/
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-1a.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-7a.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-2c.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-5i.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-3c.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-2h.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-5d.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-10a.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-3a.txt
#   inflating: ../data/raw/Training/Phase1Questions/Phase1Questions-4c.txt
#    creating: ../data/raw/Training/Phase2Questions/
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-3a.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-3c.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-2h.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-10a.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-7a.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-5i.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-5d.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-1a.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-2c.txt
#   inflating: ../data/raw/Training/Phase2Questions/Phase2Questions-4c.txt
#    creating: ../data/raw/Training/Phase2Answers/
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-2c.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-4c.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-1a.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-5i.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-2h.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-7a.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-5d.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-3a.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-10a.txt
#   inflating: ../data/raw/Training/Phase2Answers/Phase2Answers-3c.txt

# %% [markdown]
# ## Read and prepare the data

# %%
lst_files = os.listdir(PH2ANS_DIR)

# %%
lst_data_dfs = []
pairs_desc_subcat = {}

for file_name in lst_files:

    # reading answers provived by humans
    # on the questions related to
    # current subcategory
    idx = re.findall('[0-9]+[a-z]', file_name)[0]
    ans_name = f"Phase2Answers-{idx}.txt"
    ans_path = os.path.join(PH2ANS_DIR, ans_name)

    df = read_hum_answers(ans_path)
    df['file_idx'] = idx
    lst_data_dfs.append(df)

    # reading pairs describing
    # current subcategory
    q_name = f"Phase1Questions-{idx}.txt"
    q_path = os.path.join(PH1QUE_DIR, q_name)
    q_txt = read_txt_info(q_path)

    # remove correct answer
    q_pairs = re.findall('[a-z]+:[a-z]+', q_txt)
    q_pairs = ', '.join(q_pairs)
    pairs_desc_subcat[idx] = q_pairs

data = pd.concat(lst_data_dfs).reset_index(drop=True)

# %%
# extracting small subset

data = data[data['file_idx'].isin(SELECTED_IDXS)]
pairs_desc_subcat = {idx: pairs for idx, pairs in
                     pairs_desc_subcat.items()
                     if idx in SELECTED_IDXS}

# %%
data.head()
# Out:
#              pair1           pair2       pair3              pair4  \
# 5480      high:low  around:through  under:over           root:tip
# 5481      high:low  around:through  under:over           root:tip
# 5482      high:low  around:through  under:over           root:tip
# 5483      high:low  around:through  under:over           root:tip
# 5484  ahead:behind          in:out    tip:root  interior:exterior
#
#      least_illustrative most_illustrative              user_selected_relation  \
# 5480     around:through          high:low  X is the opposite direction from Y
# 5481     around:through          high:low  X is the opposite direction from Y
# 5482     around:through          high:low  X is the opposite direction from Y
# 5483     around:through          high:low  X is the opposite direction from Y
# 5484           tip:root      ahead:behind  X is the opposite direction from Y
#
#      file_idx
# 5480       4d
# 5481       4d
# 5482       4d
# 5483       4d
# 5484       4d

# %%
# remove duplicates, leave unique options only
# we need at least one human answer for each question
# in order to formulate the questions fo GPT4

options_df = data[['file_idx', 'pair1', 'pair2', 'pair3', 'pair4']]
options_df = options_df.drop_duplicates()
options_df['describing_pairs'] = options_df['file_idx'].\
    map(pairs_desc_subcat)

# %%
options_df.head()
# Out:
#      file_idx           pair1               pair2             pair3  \
# 5480       4d        high:low      around:through        under:over
# 5484       4d    ahead:behind              in:out          tip:root
# 5488       4d  around:through    backward:forward       north:south
# 5493       4d        high:low         above:below  backward:forward
# 5496       4d      top:bottom  boring:interesting         sad:happy
#
#                   pair4                                   describing_pairs
# 5480           root:tip  front:back, left:right, east:west, before:afte...
# 5484  interior:exterior  front:back, left:right, east:west, before:afte...
# 5488  interior:exterior  front:back, left:right, east:west, before:afte...
# 5493            stop:go  front:back, left:right, east:west, before:afte...
# 5496  interior:exterior  front:back, left:right, east:west, before:afte...

# %%
options_df.to_csv(os.path.join(GPTQUE_DIR, 'questions_to_gpt4.csv'),
                  index=False)

# %% [markdown]
# ## Sending the questions to GPT-4

# %%
# this loads your open api key from .env file
_ = load_dotenv(find_dotenv())
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
# receive GPT-4 answers
responses = defaultdict(list)
for line in options_df.iterrows():
    idx = line[1]['file_idx']
    describing_pairs = line[1]['describing_pairs']
    instruction = Q_TEMPLATE.format(describing_pairs)
    options = " ".join([line[1]['pair1'],
                        line[1]['pair2'],
                        line[1]['pair3'],
                        line[1]['pair4']])
    response = ask_gpt4(instruction, options)
    responses[idx].append(response)

# %%
# save the answers
for idx, subcat_responces in responses.items():
    file_name = f"Phase2Answers-{idx}.txt"
    file_path = os.path.join(GPTANS_DIR, file_name)
    write_answers(subcat_responces, file_path)
